# %% [markdown]
# # Strategy Diagnostic Notebook
#
# This notebook reproduces the charts and statistics from the diagnostic report.

# %%
import sys
import os
sys.path.append(os.path.abspath('../scripts/xueqiu'))
from strategy_diagnostic import StrategyDiagnostic

# Initialize Engine
diag = StrategyDiagnostic()

# %% [markdown]
# ## 1. Zero Volatility Diagnostics
# ### 1.1 Data Quality Check

# %%
diag.check_data_quality()

# %% [markdown]
# ### 1.2 Signal Validity

# %%
diag.check_signal_validity()

# %% [markdown]
# ### 1.4 Parameter Degradation

# %%
diag.check_parameter_degradation()

# %% [markdown]
# ## 2. Style Analysis

# %%
diag.run_style_analysis()

# %% [markdown]
# ## 3. Overfitting Tests

# %%
diag.run_overfitting_tests()

# %% [markdown]
# ## 4. Regime Analysis

# %%
diag.run_regime_analysis()
